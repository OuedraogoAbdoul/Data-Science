# %% [markdown]
# ## Application of Cross-industry standard process for data mining (CRISP-DM)

# %% [markdown]
# ###     Why CRISP-DM

# %% [markdown]
# #### Reading and Exploring the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv("../survey_results_public.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
first_five = data.head(5) # Check the fist 5 record of the data

# %%
last_five = data.tail(5) # Check the last 5 record of the data

# %%
row = data.shape[0] # Check how many rows are in the dataset
col = data.shape[1] # Check how many columns are in the dataset

# %%
row
# Out:
# 98855

# %%
col
# Out:
# 129

# %%
cols_name = data.columns # Display Columns names

# %% [markdown]
# ###### Look for missing data

# %%
data_missing = data.isnull().any() # Display the name of the colums with missing data

# %%
mos_cols_missing = set(data.columns[data.isnull().mean() > 0.90]) # Return the colum name with missing data greater than 90%

# %%
data.head(2)
# Out:
#    Respondent Hobby OpenSource         Country Student          Employment  \
# 0           1   Yes         No           Kenya      No  Employed part-time
# 1           3   Yes        Yes  United Kingdom      No  Employed full-time
#
#                             FormalEducation  \
# 0  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
#
#                                              DevType      ...        \
# 0                               Full-stack developer      ...
# 1  Database administrator;DevOps specialist;Full-...      ...
#
#                     Exercise Gender         SexualOrientation  \
# 0       3 - 4 times per week   Male  Straight or heterosexual
# ...

# %%
student_type = data.Student.value_counts()
(student_type/data.shape[0]).plot(kind="bar");
plt.title("Student Enrolement Status");

# %%
student_type = data.FormalEducation.value_counts()
(student_type/data.shape[0]).plot(kind="bar");
plt.title("Eduction Level");

# %%
student_type = data.UndergradMajor.value_counts()
(student_type/data.shape[0]).plot(kind="bar");
plt.title("School Major difference")
# Out:
# Text(0.5, 1.0, 'School Major difference')

# %%
student_type = data.Country.value_counts()
plt.figure(figsize=(30,10))
(student_type/data.shape[0]).plot(kind="bar");
plt.title("Gap in Country")
plt.show()
