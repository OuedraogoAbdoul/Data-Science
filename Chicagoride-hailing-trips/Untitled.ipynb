# %% [markdown]
# # Analysing Chicago ride-hailing trips data

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("https://data.cityofchicago.org/resource/bc6b-sq4u.csv")

# %%
data.head()
# Out:
#   color last_inspection_month    make       model month_reported  \
# 0   Red               2017-06  Nissan  Pathfinder        2017-09
# 1   NaN                   NaN  Nissan      Altima        2016-10
# 2  Gray               2017-10  Nissan      Altima        2018-01
# 3   NaN                   NaN  Toyota       Prius        2015-12
# 4  Gray               2017-09  Toyota       Camry        2017-10
#
#    multiple_tnps  number_of_trips state    year
# 0           True              NaN    IL  2016.0
# 1           True              NaN    IL  2016.0
# 2           True              NaN    IL  2014.0
# 3          False              0.0    IL  2010.0
# 4           True              NaN    IL  2012.0

# %%
data.tail()
# Out:
#     color last_inspection_month   make          model month_reported  \
# 995   NaN                   NaN  Dodge  Grand Caravan        2016-10
# 996   NaN                   NaN  Dodge  Grand Caravan        2016-10
# 997   NaN                   NaN  Dodge  Grand Caravan        2016-10
# 998   NaN                   NaN  Dodge  Grand Caravan        2016-10
# 999   NaN                   NaN  Dodge  Grand Caravan        2016-10
#
#      multiple_tnps  number_of_trips state    year
# 995          False              0.0    IL  2005.0
# 996          False              0.0    IL  2005.0
# 997          False              0.0    IL  2005.0
# 998          False              0.0    IL  2005.0
# 999          False              0.0    IL  2005.0

# %%
dataset = pd.read_csv("https://data.cityofchicago.org/resource/j6wf-834c.csv")

# %%
dataset.head()
# Out:
#        city driver_start_month month_reported  multiple_tnps  number_of_trips  \
# 0    Aurora            2015-12        2016-08          False            342.0
# 1   Chicago            2017-02        2018-01           True            391.0
# 2    Dolton            2015-03        2018-01           True            371.0
# 3  Eilmette            2017-07        2017-09          False            251.0
# 4   Chicago            2018-02        2018-06          False            332.0
#
#   state    zip
# 0    IL  60505
# 1    IL  60612
# 2    IL  60419
# 3    IL  60091
# 4    IL  60606

# %%
dataset.tail()
# Out:
#            city driver_start_month month_reported  multiple_tnps  \
# 995     Chicago            2015-07        2017-04          False
# 996     Chicago            2017-08        2017-11          False
# 997     Chicago            2016-05        2016-08          False
# 998  Crest Hill            2017-09        2018-01           True
# 999     Chicago            2017-03        2018-01           True
#
#      number_of_trips state    zip
# 995            319.0    IL  60647
# 996            631.0    IL  60611
# 997            119.0    IL  60645
# 998            159.0    IL  60403
# 999            318.0    IL  60606

# %%
datajson = pd.read_json("https://data.cityofchicago.org/resource/m6dm-c72p.csv")

# %%
datajson.head()
# Out:
#    additional_charges  dropoff_census_tract  dropoff_centroid_latitude  \
# 0                 9.1          1.703198e+10                  41.785999
# 1                 2.5                   NaN                        NaN
# 2                 3.8                   NaN                        NaN
# 3                 2.5                   NaN                        NaN
# 4                 2.5          1.703184e+10                  41.880994
#
#                            dropoff_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.75093428...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'type': 'Point', 'coordinates': [-87.63274648...
#
#    dropoff_centroid_longitude  dropoff_community_area  fare  \
# 0                  -87.750934                    56.0  47.5
# 1                         NaN                     NaN  10.0
# ...
